# %% [markdown]
# ### Understanding the problem
# ### Can someone who didn't graduate college become a data scientist?
# The answer is definitely yes there are already many of them. I won't cover that in this notebook. Instead,  I'm more interested in a question a little bit less explored and interesting.
# ### Can a data scientist that didn't graduate college be part of the top 20% best-paid data scientist? If so, How?

# %% [markdown]
# ## Gathering the Data

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
import seaborn as sns
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
so = pd.read_csv('datasets/stackover_anudevsurv_2021/survey_results_public.csv')
so_schema = pd.read_csv('datasets/stackover_anudevsurv_2021/survey_results_schema.csv')

# %% [markdown]
# ## Assessing the Data

# %%
so.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode  ...  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# 1  Other online resources (ex: videos, blogs, etc...         7  ...
# 2  Other online resources (ex: videos, blogs, etc...       NaN  ...
# 3                                                NaN       NaN  ...
# 4                            Friend or family member        17  ...
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#   ConvertedCompYearly
# 0             62268.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 48 columns]

# %%
so_schema.head()
# Out:
#      qid       qname                                           question  \
# 0  QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12    MetaInfo                                  Browser Meta Info
# 2   QID1          S1  <span style="font-size:22px; font-family: aria...
# 3   QID2  MainBranch  Which of the following options best describes ...
# 4  QID24  Employment  Which of the following best describes your cur...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR

# %%
kaggle = pd.read_csv('datasets/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)
kaggle.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                  Bachelor’s degree
# 2                                    Master’s degree
# 3                                    Master’s degree
# 4                                    Doctoral degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                              Other
# 2                            Program/Project Manager
# 3                                  Software Engineer
# 4                                 Research Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                          20+ years
# 3                                          1-3 years
# 4                                          20+ years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                                NaN
# 3                                             Python
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                NaN  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                         Q38_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                       TensorBoard
# 4                                                NaN
#
#                                         Q38_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q38_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q38_B_Part_11  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                               None
# 3                                                NaN
# 4                                               None
#
#                                          Q38_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 369 columns]

# %%
print('so shape: ', so.shape)
print('kaggle shape: ', kaggle.shape)
# Out:
# so shape:  (83439, 48)
# kaggle shape:  (25974, 369)

# %% [markdown]
# ### Understanding the Data

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(11,4))

plt.subplot(1, 2, 1)
count_vals = so['Country'].value_counts()
(count_vals[:10]/so.shape[0]).plot(kind="bar", ax=ax1);
ax1.set_title('Stack Overflow Survey')

plt.subplot(1, 2, 2)
count_vals = kaggle['Q3'].value_counts()
(count_vals[:10]/kaggle.shape[0]).plot(kind="bar", ax=ax2);
ax2.set_title('Kaggle Survey')
# Out:
# Text(0.5, 1.0, 'Kaggle Survey')

# %% [markdown]
# In both surveys, USA and India are the countries that most participated. Brazil and the UK with a high number of participants as well.
# Other than that, both surveys seem to have targeted different populations with more emerging countries on the Kaggle survey. It is going to be very helpful to evaluate both datasets.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,4))

plt.subplot(1, 2, 1)
status_vals = so['Employment'].value_counts()
(status_vals/so.shape[0]).plot(kind="bar", ax=ax1);
ax1.set_title('Stack Overflow Survey')

plt.subplot(1, 2, 2)
status_vals = kaggle['Q5'].value_counts()
(status_vals[0:-1]/kaggle.shape[0]).plot(kind="bar", ax=ax2);
ax2.set_title('Kaggle Survey');

# %%
comp_order = ['$0-999', '1,000-1,999', '2,000-2,999', '3,000-3,999', '4,000-4,999', '5,000-7,499', '7,500-9,999',
              '10,000-14,999', '15,000-19,999', '20,000-24,999', '25,000-29,999', '30,000-39,999', '40,000-49,999', 
              '50,000-59,999', '60,000-69,999', '70,000-79,999', '80,000-89,999', '90,000-99,999', '100,000-124,999',
              '125,000-149,999', '150,000-199,999', '200,000-249,999', '250,000-299,999', '300,000-499,999', 
              '$500,000-999,999', '>$1,000,000']

# %%
kaggle_ds = kaggle[kaggle['Q5']=='Data Scientist']

fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize=(13,9))
fig.suptitle('Total Compensation')
sns.countplot(x = "Q25", data = kaggle_ds[kaggle_ds['Q3'] == 'Colombia'], order = comp_order, ax=ax1).set(xlabel=None)
ax1.set_title("Colombia")
sns.countplot(x = "Q25", data = kaggle_ds[kaggle_ds['Q3'] == 'Japan'], order = comp_order, ax=ax2).set(xlabel=None)
ax2.set_title("Japan")
sns.countplot(x = "Q25", data = kaggle_ds[kaggle_ds['Q3'] == 'United States of America'], order = comp_order, ax=ax3).set(xlabel=None)
ax3.set_title("USA")
plt.xticks(rotation=90);

# %% [markdown]
# We can see that there is a tremendous gap in the total compensation a data scientist receives depending on the country they are working from.

# %% [markdown]
# # 1) What tools do the top 20% of the highest-paid data scientists and Stack Overflow Users want to work in over the next year?

# %% [markdown]
# ## Cleaning the Data

# %%
so_sub = so[['MainBranch', 'Employment', 'LearnCode', 'DevType', 'LanguageWantToWorkWith', 'DatabaseWantToWorkWith', 
           'PlatformWantToWorkWith', 'WebframeWantToWorkWith', 'MiscTechWantToWorkWith', 'ToolsTechWantToWorkWith', 
           'NEWCollabToolsWantToWorkWith', 'OpSys', 'ConvertedCompYearly']]

# %%
# We are interested in just full-employed people for this analysis.
cond = so_sub['Employment'] == 'Employed full-time'
so_sub = so_sub[cond]

# We are interested in just data scientists for this analysis. 
so_sub = so_sub[so_sub['DevType'].notna()]
so_sub = so_sub[so_sub['DevType'].str.contains('Data scientist')]

# We are interested in the 20% highest-paid data scientist for this analysis.
so_sub = so_sub[so_sub.ConvertedCompYearly > so_sub.ConvertedCompYearly.quantile(.80)]
# Out:
# (53584, 13)
# (53372, 13)

# %%
so_sub.shape
# Out:
# (508, 13)

# %% [markdown]
# ## Analyzing the Data

# %%
def create_dic_so_attr(data, interesting_attr):
    """
    INPUT:
    data - pandas dataframe 
    interesting_attr - The attribute we are interested in analyzing 
    OUTPUT:
    dic - a dictionary with the counts of each of the options of the interesting_attr
    """
    # Initialize an empty list that will be filled with possible options for the interesting_attr
    list_of_opt = []
    
    # Drop out not respondents from the data since we are interested in what people openly respond
    interesting_attr_cln = data[interesting_attr].dropna()
    
    # Iterate over each individual and save the options selected in list_of_opt
    for indiv in interesting_attr_cln:
        indiv_split = indiv.split(';')
        for opt in indiv_split:
            if opt not in list_of_opt:
                list_of_opt.append(opt)
    
    # Create an empty dictionary that will hold the value as keys and the total counts of each option as values            
    dic = {}
    
    # Iterate over each option from the list_of_opt and find the value counts of the individuals that selected that option
    for opt in list_of_opt:
        dic[opt] = interesting_attr_cln[interesting_attr_cln.str.contains(opt, regex=False)].shape[0]
    dic['TOTAL'] = len(interesting_attr_cln)
    
    # Organize the dictionary in descending order according to its value
    dic = {k: v for k, v in sorted(dic.items(), key=lambda item: item[1], reverse=True)}
    
    return dic

# %%
create_dic_so_attr(so_sub, 'LearnCode')
# Out:
# {'TOTAL': 507,
#  'Books / Physical media': 325,
#  'School': 311,
#  'Other online resources (ex: videos, blogs, etc)': 254,
#  'Online Courses or Certification': 169,
#  'Online Forum': 138,
#  'Friend or family member': 104,
#  'Colleague': 97,
#  'Other (please specify):': 60,
#  'Coding Bootcamp': 43}

# %%
def create_plot(dic, figx=12):
    """
    INPUT:
    dic - a dictionary with the counts of each of the options of the interesting_attr 
    figx - The x size of the figure to be plotted 
    OUTPUT:
    a horizontal barplot from the dictionary provided with percentages over the tick labels for each of the bars created
    """
    
    # Specify the figure size in inches for both X and Y axes
    rcParams['figure.figsize'] = figx, len(dic)/4

    # Set a uniformly high contrast pallet for the plot
    base_color = sns.color_palette()[0]
    
    # Store the TOTAL count to calculate proportions 
    tot = dic.pop('TOTAL')
    
    # Plot a horizontal barplot of the dictionary provided
    sns.barplot(list(dic.values()), list(dic.keys()), color=base_color);
    plt.xlabel('Count');

    # Logic to print the proportion text on the bars
    for i in range (len(dic.keys())):
        count = list(dic.values())[i]
        # Convert count into a percentage and then into a string
        pct_string = '{:0.1f}%'.format(100*count/tot)
        # Print the string value on the bar 
        plt.text(count+1, i, pct_string, va='center')

# %%
create_plot(create_dic_so_attr(so_sub, 'LearnCode'))

# %%
create_plot(create_dic_so_attr(so_sub, 'LanguageWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'DatabaseWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'PlatformWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'WebframeWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'MiscTechWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'ToolsTechWantToWorkWith'))

# %%
create_plot(create_dic_so_attr(so_sub, 'NEWCollabToolsWantToWorkWith'))

# %%
def rel_freq_plot(data, arg, prop_incr):
    """
    INPUT:
    data - pandas dataframe 
    arg - the argument interested in plotting 
    prop_incr - the step size of the evenly spaced proportioned values for the X-axis of the plot
    OUTPUT:
    a horizontal bar plot with the relative frequency count on the X-axis
    """
    
    # Returns the sum of all not-null values in arg column
    tot_no = data[arg].value_counts().sum()

    # Return the highest frequency in the arg column
    max_type_count = data[arg].value_counts()[0]

    # Compute the length of the longest bar in terms of the proportion
    max_prop = max_type_count / tot_no

    # Use numpy.arange() function to produce a set of evenly spaced proportioned values 
    # between 0 and max_prop, with a step size prop_incr
    tick_props = np.arange(0, max_prop, prop_incr)
    tick_props

    # Use a list comprehension to create tick_names that we will apply to the tick labels. 
    # Pick each element `v` from the `tick_props`, and convert it into a formatted string.
    # `{:0.2f}` denotes that before formatting, with 2 digits of precision and `f` is used to represent floating point number.
    tick_names = ['{:0.2f}'.format(v) for v in tick_props]

    # Set a uniformly high contrast pallet for the plot
    base_color = sns.color_palette()[0]
    
    sns.countplot(data=data, y=arg, color=base_color, order=data[arg].value_counts().index);
    # Change the tick locations and labels
    plt.xticks(tick_props * tot_no, tick_names)
    plt.xlabel('proportion');

# %%
rel_freq_plot(so_sub, 'OpSys', 0.05)

# %% [markdown]
# # 2) What tools do the top 20% of the highest-paid data scientists and kaggle users hope to become more familiar with?

# %% [markdown]
# ## Cleaning the Data

# %%
kaggle.shape
# Out:
# (25974, 369)

# %%
mapping = {'$0-999': 999, '1,000-1,999': 1999, '2,000-2,999': 2999, '3,000-3,999': 3999, '4,000-4,999': 4999, 
           '5,000-7,499': 7499, '7,500-9,999': 9999, '10,000-14,999': 14999, '15,000-19,999': 19999, 
           '20,000-24,999': 24999, '25,000-29,999': 29999, '30,000-39,999': 39999, '40,000-49,999': 49999, 
           '50,000-59,999': 59999, '60,000-69,999': 69999, '70,000-79,999': 79999, '80,000-89,999': 89999, 
           '90,000-99,999': 99999, '100,000-124,999': 124999, '125,000-149,999': 149999, '150,000-199,999': 199999, 
           '200,000-249,999': 249999, '250,000-299,999': 299999, '300,000-499,999': 499999, '$500,000-999,999': 999999, 
           '>$1,000,000': 1000001}

kg = kaggle.replace({'Q25': mapping})

# %%
ds_kg = kg[(kg['Q5'] == 'Machine Learning Engineer') | (kg['Q5'] == 'Data Scientist')]

# %%
hi_sal_ds_kg = ds_kg[ds_kg['Q25'] > ds_kg['Q25'].quantile(.80)]
hi_sal_ds_kg.shape
# Out:
# (800, 369)

# %% [markdown]
# ## Analizing the Data

# %%
def create_dic_kg(question_no, options):
    """
    INPUT:
    question_no - the question number of interest from the Kaggle survey 
    options - The number of possible options that the question_no had 
    OUTPUT:
    dic - a dictionary with the counts of each of the options of the question_no
    """
    
    # Initialize an empty list that will be filled with possible options for the interesting_attr
    dic = {}
    
    # Store in a Set the indices of the people who responded to at least one of the options
    tot = set()
    
    # Iterate over each of the answer options for the question_no and store the counts in the dictionary 'dic'
    for o in range(options):
        
        # Save the indices of the unique respondents of the question_no into the 'tot' set
        not_null_idxs = list(hi_sal_ds_kg[hi_sal_ds_kg['Q{}_Part_{}'.format(question_no, o+1)].notna()].index)
        tot.update(not_null_idxs)
        
        # Remove whitespace from the beginning and end of the option to store it clean as a key name
        key = hi_sal_ds_kg['Q{}_Part_{}'.format(question_no, o+1)].value_counts().index.tolist()[0].strip()
        
        # Store the count of the option 'o' from the question_no
        dic[key] = hi_sal_ds_kg['Q{}_Part_{}'.format(question_no, o+1)].value_counts()[0]
        
    # Create a key that stores the total people who responded to at least one of the options for the question_no
    dic['TOTAL'] = len(tot) 
    
    return {k: v for k, v in sorted(dic.items(), key=lambda item: item[1], reverse=True)}

# %%
create_plot(create_dic_kg(40, 11))

# %%
rel_freq_plot(hi_sal_ds_kg, 'Q8', 0.25)

# %%
create_plot(create_dic_kg(9, 12))

# %%
create_plot(create_dic_kg(10, 16))

# %%
create_plot(create_dic_kg(14, 11))

# %%
create_plot(create_dic_kg(16, 17))

# %%
create_plot(create_dic_kg(17, 11))

# %% [markdown]
# Want to use

# %%
create_plot(create_dic_kg('27_B', 9))

# %%
rel_freq_plot(hi_sal_ds_kg, 'Q28', 0.05)

# %%
create_plot(create_dic_kg('29_B', 4))

# %%
create_plot(create_dic_kg('31_B', 9))

# %%
create_plot(create_dic_kg('32_B', 20))

# %%
create_plot(create_dic_kg('34_B', 8))

# %%
create_plot(create_dic_kg('36_B', 7))

# %%
create_plot(create_dic_kg('37_B', 7))

# %%
create_plot(create_dic_kg('38_B', 11))

# %% [markdown]
# # 3) What tools are used by the top 20% of the highest-paid data scientists Kagglers that didn't graduate collegue in India and USA?

# %% [markdown]
# ## Cleaning the Data

# %%
in_ds_kg = ds_kg[ds_kg['Q3'] == 'India']
usa_ds_kg = ds_kg[ds_kg['Q3'] == 'United States of America']

# %%
hi_sal_in_ds_kg = in_ds_kg[in_ds_kg['Q25'] > in_ds_kg['Q25'].quantile(.80)]
hi_sal_us_ds_kg = usa_ds_kg[usa_ds_kg['Q25'] > usa_ds_kg['Q25'].quantile(.80)]

# %%
print(in_ds_kg['Q25'].quantile(.80))
print(usa_ds_kg['Q25'].quantile(.80))
# Out:
# 24999.0
# 199999.0

# %%
hi_sal_in_ds_kg.shape
# Out:
# (195, 369)

# %%
hi_sal_us_ds_kg.shape
# Out:
# (101, 369)

# %%
hi_sal_in_ds_kg_no_clg = hi_sal_in_ds_kg[(hi_sal_in_ds_kg['Q4'] == 'No formal education past high school') | (hi_sal_in_ds_kg['Q4'] == 'Some college/university study without earning a bachelor’s degree')]
hi_sal_us_ds_kg_no_clg = hi_sal_us_ds_kg[(hi_sal_us_ds_kg['Q4'] == 'No formal education past high school') | (hi_sal_us_ds_kg['Q4'] == 'Some college/university study without earning a bachelor’s degree')]

# %%
hs_no_clg_ds = hi_sal_in_ds_kg_no_clg.append(hi_sal_us_ds_kg_no_clg)

# %%
hs_no_clg_ds
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 9321                                  495  45-49  Man
# 17254                                 968  40-44  Man
# 23908                                 722  30-34  Man
# 3557                                 2547  40-44  Man
# 7857                                  552  30-34  Man
#
#                              Q3  \
# 9321                      India
# 17254                     India
# 23908                     India
# 3557   United States of America
# 7857   United States of America
#
#                                                       Q4  \
# 9321   Some college/university study without earning ...
# 17254  Some college/university study without earning ...
# 23908  Some college/university study without earning ...
# 3557   Some college/university study without earning ...
# 7857   Some college/university study without earning ...
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 9321              Data Scientist   5-10 years    Python         R       NaN
# 17254             Data Scientist    < 1 years    Python       NaN       NaN
# 23908             Data Scientist    3-5 years    Python       NaN       SQL
# 3557   Machine Learning Engineer    20+ years    Python       NaN       NaN
# 7857              Data Scientist  10-20 years    Python         R       SQL
#
#        ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 9321   ...          NaN          NaN            NaN          NaN          NaN
# 17254  ...          NaN          NaN   TensorBoard           NaN          NaN
# 23908  ...          NaN          NaN   TensorBoard           NaN          NaN
# 3557   ...          NaN          NaN            NaN          NaN          NaN
# 7857   ...          NaN          NaN            NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 9321           NaN          NaN           NaN           NaN         NaN
# 17254          NaN          NaN           NaN           NaN         NaN
# 23908          NaN          NaN       MLflow            NaN         NaN
# 3557           NaN          NaN           NaN           NaN         NaN
# 7857           NaN          NaN           NaN           NaN         NaN
#
# [5 rows x 369 columns]

# %% [markdown]
# ## Analazing the Data

# %%
common = []
for c in hs_no_clg_ds.columns:
    if hs_no_clg_ds[c].value_counts().shape != (0,):
        if hs_no_clg_ds[c].value_counts().iloc[0]>=4:
            common.append(c)
hs_no_clg_ds[common]
# Out:
#         Q2                                                 Q4  \
# 9321   Man  Some college/university study without earning ...
# 17254  Man  Some college/university study without earning ...
# 23908  Man  Some college/university study without earning ...
# 3557   Man  Some college/university study without earning ...
# 7857   Man  Some college/university study without earning ...
#
#                               Q5 Q7_Part_1      Q8         Q9_Part_11  \
# 9321              Data Scientist    Python  Python   Jupyter Notebook
# 17254             Data Scientist    Python  Python   Jupyter Notebook
# 23908             Data Scientist    Python     SQL   Jupyter Notebook
# 3557   Machine Learning Engineer    Python  Python   Jupyter Notebook
# 7857              Data Scientist    Python  Python   Jupyter Notebook
#
#       Q14_Part_2       Q16_Part_1     Q16_Part_2 Q16_Part_7  \
# 9321    Seaborn     Scikit-learn     TensorFlow    Xgboost
# 17254   Seaborn               NaN    TensorFlow         NaN
# 23908        NaN    Scikit-learn             NaN   Xgboost
# 3557    Seaborn     Scikit-learn     TensorFlow    Xgboost
# 7857    Seaborn     Scikit-learn     TensorFlow    Xgboost
#
#                           Q17_Part_1                        Q17_Part_2  \
# 9321   Linear or Logistic Regression  Decision Trees or Random Forests
# 17254  Linear or Logistic Regression  Decision Trees or Random Forests
# 23908  Linear or Logistic Regression  Decision Trees or Random Forests
# 3557   Linear or Logistic Regression  Decision Trees or Random Forests
# 7857                             NaN  Decision Trees or Random Forests
#
#                                               Q17_Part_3  \
# 9321   Gradient Boosting Machines (xgboost, lightgbm,...
# 17254  Gradient Boosting Machines (xgboost, lightgbm,...
# 23908  Gradient Boosting Machines (xgboost, lightgbm,...
# 3557   Gradient Boosting Machines (xgboost, lightgbm,...
# 7857   Gradient Boosting Machines (xgboost, lightgbm,...
#
#                                               Q24_Part_1 Q40_Part_1  \
# 9321   Analyze and understand data to influence produ...   Coursera
# 17254                                                NaN   Coursera
# 23908  Analyze and understand data to influence produ...   Coursera
# 3557   Analyze and understand data to influence produ...   Coursera
# 7857   Analyze and understand data to influence produ...   Coursera
#
#                                               Q42_Part_6
# 9321                                                 NaN
# 17254  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23908  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 3557   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 7857   YouTube (Kaggle YouTube, Cloud AI Adventures, ...

# %% [markdown]
# # 4) What tools are used by the top 20% of the highest-paid data scientists Stack Overflow users that didn't graduate collegue in India and USA?
# Consider a violin plot of india and USA comp

# %% [markdown]
# ## Cleaning the Data

# %%
# We are interested in just full-employed people for this analysis.
cond = so['Employment'] == 'Employed full-time'
so_work = so[cond]

# We are interested in the 20% highest-paid data scientist for this analysis.
so_work = so_work[so_work['DevType'].notna()]
so_work = so_work[so_work['DevType'].str.contains('Data scientist')]

# %%
so_work_in = so_work[so_work['Country'] == 'India']
so_work_usa = so_work[so_work['Country'] == 'United States of America']

# %%
# We are interested in just data scientists for this analysis. 
so_work_in_hi_sal = so_work_in[so_work_in.ConvertedCompYearly > so_work_in.ConvertedCompYearly.quantile(.80)]
so_work_usa_hi_sal = so_work_usa[so_work_usa.ConvertedCompYearly > so_work_usa.ConvertedCompYearly.quantile(.80)]
print(so_work_in_hi_sal.shape)
print(so_work_usa_hi_sal.shape)
# Out:
# (44, 48)
# (119, 48)

# %%
cond1 = so_work_usa_hi_sal['EdLevel'] == 'Some college/university study without earning a degree'
cond2 = so_work_usa_hi_sal['EdLevel'] == 'Something else'

# %%
so_work_in_hi_sal['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)       23
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    18
# Other doctoral degree (Ph.D., Ed.D., etc.)          3
# Name: EdLevel, dtype: int64

# %%
so_work_usa_hi_sal['EdLevel'].value_counts()
# Out:
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           46
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)              37
# Other doctoral degree (Ph.D., Ed.D., etc.)                29
# Some college/university study without earning a degree     4
# Professional degree (JD, MD, etc.)                         2
# Something else                                             1
# Name: EdLevel, dtype: int64

# %%
so_work_interesting = so_work_usa_hi_sal[cond1 | cond2]
so_work_interesting
# Out:
#        ResponseId                      MainBranch          Employment  \
# 10282       10283  I am a developer by profession  Employed full-time
# 19284       19285  I am a developer by profession  Employed full-time
# 39169       39170  I am a developer by profession  Employed full-time
# 52317       52318  I am a developer by profession  Employed full-time
# 78296       78297  I am a developer by profession  Employed full-time
#
#                         Country    US_State UK_Country  \
# 10282  United States of America     Florida        NaN
# 19284  United States of America    Maryland        NaN
# 39169  United States of America  New Jersey        NaN
# 52317  United States of America  New Mexico        NaN
# 78296  United States of America  Washington        NaN
#
#                                                  EdLevel     Age1stCode  \
# 10282  Some college/university study without earning ...  11 - 17 years
# 19284                                     Something else  11 - 17 years
# 39169  Some college/university study without earning ...  11 - 17 years
# 52317  Some college/university study without earning ...   5 - 10 years
# 78296  Some college/university study without earning ...   5 - 10 years
#
#                                                LearnCode YearsCode  ...  \
# 10282                             Books / Physical media        20  ...
# 19284  Coding Bootcamp;Other online resources (ex: vi...        12  ...
# 39169                      School;Books / Physical media        22  ...
# 52317     Friend or family member;Books / Physical media        35  ...
# 78296  Other online resources (ex: videos, blogs, etc...        35  ...
#
#                    Age Gender Trans                Sexuality  \
# 10282  25-34 years old    Man    No  Straight / Heterosexual
# 19284  35-44 years old    Man    No  Straight / Heterosexual
# 39169  45-54 years old    Man    No  Straight / Heterosexual
# 52317  45-54 years old    Man    No                 Bisexual
# 78296  35-44 years old    Man    No  Straight / Heterosexual
#
#                                                Ethnicity      Accessibility  \
# 10282                       White or of European descent  None of the above
# 19284  White or of European descent;Indigenous (such ...  None of the above
# 39169                       White or of European descent  None of the above
# 52317                       White or of European descent  None of the above
# 78296  White or of European descent;Hispanic or Latin...  None of the above
#
#                                             MentalHealth  \
# 10282                                  None of the above
# 19284                             Or, in your own words:
# 39169                                  None of the above
# 52317  I have a concentration and/or memory disorder ...
# 78296  I have a mood or emotional disorder (e.g. depr...
#
#                 SurveyLength SurveyEase ConvertedCompYearly
# 10282  Appropriate in length       Easy           1200000.0
# 19284  Appropriate in length       Easy            210000.0
# 39169  Appropriate in length       Easy            400000.0
# 52317              Too short       Easy            240000.0
# 78296  Appropriate in length       Easy            215000.0
#
# [5 rows x 48 columns]

# %%
interesting_attr = ['Age1stCode', 'LearnCode', 'YearsCode','YearsCodePro', 'DevType', 'OrgSize', 'LanguageHaveWorkedWith', 
 'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith', 'MiscTechHaveWorkedWith',
 'ToolsTechHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith', 'OpSys', 'Age']

# %%
so_work_interesting = so_work_interesting[interesting_attr]

# %%
so_work_interesting
# Out:
#           Age1stCode                                          LearnCode  \
# 10282  11 - 17 years                             Books / Physical media
# 19284  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...
# 39169  11 - 17 years                      School;Books / Physical media
# 52317   5 - 10 years     Friend or family member;Books / Physical media
# 78296   5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#       YearsCode YearsCodePro  \
# 10282        20            8
# 19284        12            9
# 39169        22           18
# 52317        35           30
# 78296        35           20
#
#                                                  DevType  \
# 10282  Engineer, data;Data scientist or machine learn...
# 19284      Data scientist or machine learning specialist
# 39169  Developer, front-end;Developer, desktop or ent...
# 52317  Developer, desktop or enterprise applications;...
# 78296  Developer, full-stack;Data scientist or machin...
#
#                         OrgSize  \
# 10282  1,000 to 4,999 employees
# 19284  1,000 to 4,999 employees
# 39169        10 to 19 employees
# 52317        20 to 99 employees
# 78296      500 to 999 employees
#
#                                   LanguageHaveWorkedWith  \
# 10282                           Go;Java;Python;Scala;SQL
# 19284  Bash/Shell;Java;Node.js;PHP;PowerShell;Python;...
# 39169  C;C++;Delphi;HTML/CSS;Java;JavaScript;Node.js;...
# 52317  Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Node.j...
# 78296              Bash/Shell;Clojure;Java;LISP;Ruby;SQL
#
#                                   DatabaseHaveWorkedWith  \
# 10282                                                NaN
# 19284       Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 39169                                              MySQL
# 52317  Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 78296                                 MongoDB;PostgreSQL
#
#                           PlatformHaveWorkedWith  \
# 10282                  AWS;Google Cloud Platform
# 19284  AWS;Google Cloud Platform;Microsoft Azure
# 39169                                        AWS
# 52317                                        AWS
# 78296                                        AWS
#
#                     WebframeHaveWorkedWith  \
# 10282                                  NaN
# 19284                Angular;Django;jQuery
# 39169                      Angular;ASP.NET
# 52317  Angular;Angular.js;ASP.NET;React.js
# 78296                        Ruby on Rails
#
#                                   MiscTechHaveWorkedWith  \
# 10282  Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 19284  Apache Spark;Cordova;Keras;NumPy;Pandas;Tensor...
# 39169                                                NaN
# 52317                                  .NET Framework;Qt
# 78296                                                NaN
#
#        ToolsTechHaveWorkedWith  \
# 10282           Git;Kubernetes
# 19284               Docker;Git
# 39169                      NaN
# 52317      Docker;Git;Unity 3D
# 78296  Ansible;Chef;Docker;Git
#
#                             NEWCollabToolsHaveWorkedWith    OpSys  \
# 10282                IntelliJ;PyCharm;Visual Studio Code    MacOS
# 19284  Atom;Eclipse;IntelliJ;IPython/Jupyter;Notepad+...    MacOS
# 39169               Notepad++;Sublime Text;Visual Studio  Windows
# 52317  PHPStorm;Vim;Visual Studio;Visual Studio Code;...  Windows
# 78296                                              Emacs    MacOS
#
#                    Age
# 10282  25-34 years old
# 19284  35-44 years old
# 39169  45-54 years old
# 52317  45-54 years old
# 78296  35-44 years old

# %% [markdown]
# ## Analizing the Data

# %%
create_dic_so_attr(so_work_interesting, 'LearnCode')
# Out:
# {'Books / Physical media': 5,
#  'TOTAL': 5,
#  'Other online resources (ex: videos, blogs, etc)': 2,
#  'School': 2,
#  'Online Courses or Certification': 2,
#  'Friend or family member': 2,
#  'Coding Bootcamp': 1,
#  'Other (please specify):': 1,
#  'Online Forum': 1,
#  'Colleague': 1}

# %%
create_dic_so_attr(so_work_interesting, 'DevType')
# Out:
# {'Data scientist or machine learning specialist': 5,
#  'TOTAL': 5,
#  'Developer, full-stack': 3,
#  'Data or business analyst': 3,
#  'Developer, back-end': 2,
#  'Developer, desktop or enterprise applications': 2,
#  'Engineer, data': 1,
#  'Developer, front-end': 1,
#  'Designer': 1,
#  'Database administrator': 1,
#  'Developer, game or graphics': 1}

# %%
create_dic_so_attr(so_work_interesting, 'LanguageHaveWorkedWith')
# Out:
# {'Java': 5,
#  'SQL': 5,
#  'TOTAL': 5,
#  'Python': 3,
#  'Bash/Shell': 3,
#  'Node.js': 3,
#  'PHP': 3,
#  'C': 3,
#  'R': 2,
#  'C++': 2,
#  'HTML/CSS': 2,
#  'JavaScript': 2,
#  'Go': 1,
#  'Scala': 1,
#  'PowerShell': 1,
#  'Delphi': 1,
#  'C#': 1,
#  'Perl': 1,
#  'TypeScript': 1,
#  'Clojure': 1,
#  'LISP': 1,
#  'Ruby': 1}

# %%
create_dic_so_attr(so_work_interesting, 'DatabaseHaveWorkedWith')
# Out:
# {'TOTAL': 4,
#  'MySQL': 3,
#  'PostgreSQL': 3,
#  'Microsoft SQL Server': 2,
#  'SQLite': 1,
#  'Elasticsearch': 1,
#  'MariaDB': 1,
#  'Oracle': 1,
#  'Redis': 1,
#  'MongoDB': 1}

# %%
create_dic_so_attr(so_work_interesting, 'PlatformHaveWorkedWith')
# Out:
# {'AWS': 5, 'TOTAL': 5, 'Google Cloud Platform': 2, 'Microsoft Azure': 1}

# %%
create_dic_so_attr(so_work_interesting, 'WebframeHaveWorkedWith')
# Out:
# {'TOTAL': 4,
#  'Angular': 3,
#  'ASP.NET': 2,
#  'Django': 1,
#  'jQuery': 1,
#  'Angular.js': 1,
#  'React.js': 1,
#  'Ruby on Rails': 1}

# %%
create_dic_so_attr(so_work_interesting, 'MiscTechHaveWorkedWith')
# Out:
# {'TOTAL': 3,
#  'Apache Spark': 2,
#  'Keras': 2,
#  'NumPy': 2,
#  'Pandas': 2,
#  'TensorFlow': 2,
#  'Torch/PyTorch': 2,
#  'Cordova': 1,
#  '.NET Framework': 1,
#  'Qt': 1}

# %%
create_dic_so_attr(so_work_interesting, 'ToolsTechHaveWorkedWith')
# Out:
# {'Git': 4,
#  'TOTAL': 4,
#  'Docker': 3,
#  'Kubernetes': 1,
#  'Unity 3D': 1,
#  'Ansible': 1,
#  'Chef': 1}

# %%
create_dic_so_attr(so_work_interesting, 'NEWCollabToolsHaveWorkedWith')
# Out:
# {'TOTAL': 5,
#  'Visual Studio': 3,
#  'IntelliJ': 2,
#  'PyCharm': 2,
#  'Visual Studio Code': 2,
#  'Notepad++': 2,
#  'Sublime Text': 2,
#  'Vim': 2,
#  'Atom': 1,
#  'Eclipse': 1,
#  'IPython/Jupyter': 1,
#  'RStudio': 1,
#  'TextMate': 1,
#  'PHPStorm': 1,
#  'Webstorm': 1,
#  'Emacs': 1}

# %%
create_dic_so_attr(so_work_interesting, 'OpSys')
# Out:
# {'TOTAL': 5, 'MacOS': 3, 'Windows': 2}

# %%
so_work_interesting[['Age1stCode', 'YearsCode', 'YearsCodePro', 'Age']]
# Out:
#           Age1stCode YearsCode YearsCodePro              Age
# 10282  11 - 17 years        20            8  25-34 years old
# 19284  11 - 17 years        12            9  35-44 years old
# 39169  11 - 17 years        22           18  45-54 years old
# 52317   5 - 10 years        35           30  45-54 years old
# 78296   5 - 10 years        35           20  35-44 years old

# %% [markdown]
# # Sharing and Visualizing

# %% [markdown]
# ### Preparing the data
